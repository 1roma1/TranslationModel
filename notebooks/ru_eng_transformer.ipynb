# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install tensorflow_datasets
# !pip install tensorflow_text
# Out:
# Requirement already satisfied: tensorflow_datasets in /usr/local/lib/python3.7/dist-packages (4.0.1)
# Requirement already satisfied: tensorflow-metadata in /usr/local/lib/python3.7/dist-packages (from tensorflow_datasets) (1.5.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from tensorflow_datasets) (1.19.5)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from tensorflow_datasets) (0.16.0)
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow_datasets) (3.17.3)
# Requirement already satisfied: attrs>=18.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow_datasets) (21.4.0)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow_datasets) (2.23.0)
# Requirement already satisfied: promise in /usr/local/lib/python3.7/dist-packages (from tensorflow_datasets) (2.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from tensorflow_datasets) (4.62.3)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.7/dist-packages (from tensorflow_datasets) (5.4.0)
# Requirement already satisfied: dm-tree in /usr/local/lib/python3.7/dist-packages (from tensorflow_datasets) (0.1.6)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from tensorflow_datasets) (1.15.0)
# Requirement already satisfied: dill in /usr/local/lib/python3.7/dist-packages (from tensorflow_datasets) (0.3.4)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.7/dist-packages (from tensorflow_datasets) (1.1.0)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.7/dist-packages (from tensorflow_datasets) (0.12.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->tensorflow_datasets) (2021.10.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->tensorflow_datasets) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->tensorflow_datasets) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->tensorflow_datasets) (2.10)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.7/dist-packages (from importlib-resources->tensorflow_datasets) (3.7.0)
# Requirement already satisfied: googleapis-common-protos<2,>=1.52.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-metadata->tensorflow_datasets) (1.54.0)
# Collecting tensorflow_text
#   Downloading tensorflow_text-2.7.3-cp37-cp37m-manylinux2010_x86_64.whl (4.9 MB)
#      |████████████████████████████████| 4.9 MB 4.0 MB/s
# Requirement already satisfied: tensorflow<2.8,>=2.7.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow_text) (2.7.0)
# Requirement already satisfied: tensorflow-hub>=0.8.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow_text) (0.12.0)
# Requirement already satisfied: wheel<1.0,>=0.32.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.8,>=2.7.0->tensorflow_text) (0.37.1)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.8,>=2.7.0->tensorflow_text) (1.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.8,>=2.7.0->tensorflow_text) (3.10.0.2)
# Requirement already satisfied: absl-py>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.8,>=2.7.0->tensorflow_text) (0.12.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.8,>=2.7.0->tensorflow_text) (0.2.0)
# Requirement already satisfied: gast<0.5.0,>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.8,>=2.7.0->tensorflow_text) (0.4.0)
# Requirement already satisfied: tensorboard~=2.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.8,>=2.7.0->tensorflow_text) (2.7.0)
# Requirement already satisfied: protobuf>=3.9.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.8,>=2.7.0->tensorflow_text) (3.17.3)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.8,>=2.7.0->tensorflow_text) (1.6.3)
# Requirement already satisfied: libclang>=9.0.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.8,>=2.7.0->tensorflow_text) (12.0.0)
# Requirement already satisfied: flatbuffers<3.0,>=1.12 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.8,>=2.7.0->tensorflow_text) (2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.8,>=2.7.0->tensorflow_text) (1.15.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.8,>=2.7.0->tensorflow_text) (3.3.0)
# Requirement already satisfied: tensorflow-estimator<2.8,~=2.7.0rc0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.8,>=2.7.0->tensorflow_text) (2.7.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.8,>=2.7.0->tensorflow_text) (3.1.0)
# Requirement already satisfied: numpy>=1.14.5 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.8,>=2.7.0->tensorflow_text) (1.19.5)
# Requirement already satisfied: keras<2.8,>=2.7.0rc0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.8,>=2.7.0->tensorflow_text) (2.7.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.21.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.8,>=2.7.0->tensorflow_text) (0.23.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.8,>=2.7.0->tensorflow_text) (1.43.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.8,>=2.7.0->tensorflow_text) (1.1.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.8,>=2.7.0->tensorflow_text) (1.13.3)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py>=2.9.0->tensorflow<2.8,>=2.7.0->tensorflow_text) (1.5.2)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow<2.8,>=2.7.0->tensorflow_text) (0.4.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow<2.8,>=2.7.0->tensorflow_text) (2.23.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow<2.8,>=2.7.0->tensorflow_text) (1.35.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow<2.8,>=2.7.0->tensorflow_text) (0.6.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow<2.8,>=2.7.0->tensorflow_text) (3.3.6)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow<2.8,>=2.7.0->tensorflow_text) (57.4.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow<2.8,>=2.7.0->tensorflow_text) (1.0.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow<2.8,>=2.7.0->tensorflow_text) (1.8.1)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow<2.8,>=2.7.0->tensorflow_text) (4.2.4)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow<2.8,>=2.7.0->tensorflow_text) (4.8)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow<2.8,>=2.7.0->tensorflow_text) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow<2.8,>=2.7.0->tensorflow_text) (1.3.0)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard~=2.6->tensorflow<2.8,>=2.7.0->tensorflow_text) (4.10.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard~=2.6->tensorflow<2.8,>=2.7.0->tensorflow_text) (3.7.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow<2.8,>=2.7.0->tensorflow_text) (0.4.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow<2.8,>=2.7.0->tensorflow_text) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow<2.8,>=2.7.0->tensorflow_text) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow<2.8,>=2.7.0->tensorflow_text) (2021.10.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow<2.8,>=2.7.0->tensorflow_text) (2.10)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow<2.8,>=2.7.0->tensorflow_text) (3.1.1)
# Installing collected packages: tensorflow-text
# Successfully installed tensorflow-text-2.7.3

# %%
import collections
import logging
import os
import pathlib 
import re 
import string
import sys 
import time 

import numpy as np
import matplotlib.pyplot as plt 

import tensorflow_datasets as tfds 
import tensorflow_text as text 
import tensorflow as tf

from drive.MyDrive.transformer.transformer import Transformer
from drive.MyDrive.transformer.scheduler import CustomSchedule

# %%
logging.getLogger('tensorflow').setLevel(logging.ERROR)

# %%
examples, metadata = tfds.load('ted_hrlr_translate/ru_to_en', with_info=True,
                               as_supervised=True)
train_examples, val_examples = examples['train'], examples['validation']
# Out:
# Downloading and preparing dataset ted_hrlr_translate/ru_to_en/1.0.0 (download: 124.94 MiB, generated: Unknown size, total: 124.94 MiB) to /root/tensorflow_datasets/ted_hrlr_translate/ru_to_en/1.0.0...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# 0 examples [00:00, ? examples/s]
# Shuffling and writing examples to /root/tensorflow_datasets/ted_hrlr_translate/ru_to_en/1.0.0.incompleteVDAMLI/ted_hrlr_translate-train.tfrecord
#   0%|          | 0/208106 [00:00<?, ? examples/s]
# 0 examples [00:00, ? examples/s]
# Shuffling and writing examples to /root/tensorflow_datasets/ted_hrlr_translate/ru_to_en/1.0.0.incompleteVDAMLI/ted_hrlr_translate-validation.tfrecord
#   0%|          | 0/4805 [00:00<?, ? examples/s]
# 0 examples [00:00, ? examples/s]
# Shuffling and writing examples to /root/tensorflow_datasets/ted_hrlr_translate/ru_to_en/1.0.0.incompleteVDAMLI/ted_hrlr_translate-test.tfrecord
#   0%|          | 0/5476 [00:00<?, ? examples/s]
# Dataset ted_hrlr_translate downloaded and prepared to /root/tensorflow_datasets/ted_hrlr_translate/ru_to_en/1.0.0. Subsequent calls will reuse this data.

# %%
model_name = 'drive/MyDrive/ru_en_bert_converter'
tokenizers = tf.saved_model.load(model_name)

# %%
def tokenize_pairs(ru, en):
    ru = tokenizers.ru.tokenize(ru)
    ru = ru.to_tensor()

    en = tokenizers.en.tokenize(en)
    en = en.to_tensor()
    return ru, en

# %%
BUFFER_SIZE = 20000
BATCH_SIZE = 64
EPOCHS = 10

# %%
def make_batches(ds):
  return (
      ds
      .cache()
      .shuffle(BUFFER_SIZE)
      .batch(BATCH_SIZE)
      .map(tokenize_pairs, num_parallel_calls=tf.data.AUTOTUNE)
      .prefetch(tf.data.AUTOTUNE))
    
train_batches = make_batches(train_examples)
val_batches = make_batches(val_examples)

# %%
num_layers = 4
d_model = 128
dff = 512
num_heads = 8
dropout_rate = 0.1

# %%
learning_rate = CustomSchedule(d_model)

optimizer = tf.keras.optimizers.Adam(learning_rate, beta_1=0.9, beta_2=0.98,
                                     epsilon=1e-9)

loss_object = tf.keras.losses.SparseCategoricalCrossentropy(
    from_logits=True, reduction='none')

# %%
train_loss = tf.keras.metrics.Mean(name='train_loss')
train_accuracy = tf.keras.metrics.Mean(name='train_accuracy')

# %%
transformer = Transformer(
    num_layers=num_layers,
    d_model=d_model,
    num_heads=num_heads,
    dff=dff,
    input_vocab_size=tokenizers.ru.get_vocab_size().numpy(),
    target_vocab_size=tokenizers.en.get_vocab_size().numpy(),
    pe_input=1000,
    pe_target=1000,
    rate=dropout_rate)

# %%
checkpoint_path = "./checkpoints/train"

ckpt = tf.train.Checkpoint(transformer=transformer,
                           optimizer=optimizer)

ckpt_manager = tf.train.CheckpointManager(ckpt, checkpoint_path, max_to_keep=5)

# %%
def loss_function(real, pred):
    mask = tf.math.logical_not(tf.math.equal(real, 0))
    loss_ = loss_object(real, pred)

    mask = tf.cast(mask, dtype=loss_.dtype)
    loss_ *= mask

    return tf.reduce_sum(loss_)/tf.reduce_sum(mask)


def accuracy_function(real, pred):
    accuracies = tf.equal(real, tf.argmax(pred, axis=2))

    mask = tf.math.logical_not(tf.math.equal(real, 0))
    accuracies = tf.math.logical_and(mask, accuracies)

    accuracies = tf.cast(accuracies, dtype=tf.float32)
    mask = tf.cast(mask, dtype=tf.float32)
    return tf.reduce_sum(accuracies)/tf.reduce_sum(mask)

# %%
train_step_signature = [
    tf.TensorSpec(shape=(None, None), dtype=tf.int64),
    tf.TensorSpec(shape=(None, None), dtype=tf.int64),
]


@tf.function(input_signature=train_step_signature)
def train_step(inp, tar):
  tar_inp = tar[:, :-1]
  tar_real = tar[:, 1:]

  with tf.GradientTape() as tape:
    predictions = transformer([inp, tar_inp],
                                 training = True)
    loss = loss_function(tar_real, predictions)

  gradients = tape.gradient(loss, transformer.trainable_variables)
  optimizer.apply_gradients(zip(gradients, transformer.trainable_variables))

  train_loss(loss)
  train_accuracy(accuracy_function(tar_real, predictions))

# %%
for epoch in range(EPOCHS):
  start = time.time()

  train_loss.reset_states()
  train_accuracy.reset_states()

  for (batch, (inp, tar)) in enumerate(train_batches):
    train_step(inp, tar)

    if batch % 50 == 0:
      print(f'Epoch {epoch + 1} Batch {batch} Loss {train_loss.result():.4f} Accuracy {train_accuracy.result():.4f}')

  if (epoch + 1) % 5 == 0:
    ckpt_save_path = ckpt_manager.save()
    print(f'Saving checkpoint for epoch {epoch+1} at {ckpt_save_path}')

  print(f'Epoch {epoch + 1} Loss {train_loss.result():.4f} Accuracy {train_accuracy.result():.4f}')

  print(f'Time taken for 1 epoch: {time.time() - start:.2f} secs\n')
# Out:
# Epoch 1 Batch 0 Loss 8.9853 Accuracy 0.0006
# Epoch 1 Batch 50 Loss 8.9244 Accuracy 0.0049
# Epoch 1 Batch 100 Loss 8.8124 Accuracy 0.0225
# Epoch 1 Batch 150 Loss 8.6907 Accuracy 0.0284
# Epoch 1 Batch 200 Loss 8.5421 Accuracy 0.0315
# Epoch 1 Batch 250 Loss 8.3674 Accuracy 0.0333
# Epoch 1 Batch 300 Loss 8.1728 Accuracy 0.0344
# Epoch 1 Batch 350 Loss 7.9723 Accuracy 0.0352
# Epoch 1 Batch 400 Loss 7.7803 Accuracy 0.0383
# Epoch 1 Batch 450 Loss 7.6060 Accuracy 0.0471
# Epoch 1 Batch 500 Loss 7.4542 Accuracy 0.0568
# Epoch 1 Batch 550 Loss 7.3139 Accuracy 0.0663
# Epoch 1 Batch 600 Loss 7.1856 Accuracy 0.0753
# Epoch 1 Batch 650 Loss 7.0644 Accuracy 0.0834
# Epoch 1 Batch 700 Loss 6.9518 Accuracy 0.0908
# Epoch 1 Batch 750 Loss 6.8484 Accuracy 0.0975
# Epoch 1 Batch 800 Loss 6.7513 Accuracy 0.1039
# Epoch 1 Batch 850 Loss 6.6632 Accuracy 0.1100
# Epoch 1 Batch 900 Loss 6.5827 Accuracy 0.1157
# Epoch 1 Batch 950 Loss 6.5061 Accuracy 0.1214
# Epoch 1 Batch 1000 Loss 6.4351 Accuracy 0.1266
# Epoch 1 Batch 1050 Loss 6.3706 Accuracy 0.1314
# Epoch 1 Batch 1100 Loss 6.3079 Accuracy 0.1360
# Epoch 1 Batch 1150 Loss 6.2491 Accuracy 0.1404
# Epoch 1 Batch 1200 Loss 6.1947 Accuracy 0.1445
# Epoch 1 Batch 1250 Loss 6.1436 Accuracy 0.1483
# Epoch 1 Batch 1300 Loss 6.0952 Accuracy 0.1518
# Epoch 1 Batch 1350 Loss 6.0493 Accuracy 0.1552
# Epoch 1 Batch 1400 Loss 6.0058 Accuracy 0.1586
# Epoch 1 Batch 1450 Loss 5.9644 Accuracy 0.1616
# Epoch 1 Batch 1500 Loss 5.9245 Accuracy 0.1647
# Epoch 1 Batch 1550 Loss 5.8859 Accuracy 0.1676
# Epoch 1 Batch 1600 Loss 5.8495 Accuracy 0.1703
# Epoch 1 Batch 1650 Loss 5.8164 Accuracy 0.1727
# Epoch 1 Batch 1700 Loss 5.7840 Accuracy 0.1751
# Epoch 1 Batch 1750 Loss 5.7518 Accuracy 0.1775
# Epoch 1 Batch 1800 Loss 5.7213 Accuracy 0.1798
# Epoch 1 Batch 1850 Loss 5.6907 Accuracy 0.1822
# Epoch 1 Batch 1900 Loss 5.6621 Accuracy 0.1844
# Epoch 1 Batch 1950 Loss 5.6341 Accuracy 0.1864
# Epoch 1 Batch 2000 Loss 5.6076 Accuracy 0.1885
# Epoch 1 Batch 2050 Loss 5.5822 Accuracy 0.1904
# Epoch 1 Batch 2100 Loss 5.5575 Accuracy 0.1923
# Epoch 1 Batch 2150 Loss 5.5337 Accuracy 0.1941
# Epoch 1 Batch 2200 Loss 5.5109 Accuracy 0.1958
# Epoch 1 Batch 2250 Loss 5.4886 Accuracy 0.1975
# Epoch 1 Batch 2300 Loss 5.4673 Accuracy 0.1991
# Epoch 1 Batch 2350 Loss 5.4463 Accuracy 0.2007
# Epoch 1 Batch 2400 Loss 5.4263 Accuracy 0.2021
# Epoch 1 Batch 2450 Loss 5.4057 Accuracy 0.2036
# Epoch 1 Batch 2500 Loss 5.3862 Accuracy 0.2051
# Epoch 1 Batch 2550 Loss 5.3670 Accuracy 0.2065
# Epoch 1 Batch 2600 Loss 5.3482 Accuracy 0.2080
# Epoch 1 Batch 2650 Loss 5.3298 Accuracy 0.2093
# Epoch 1 Batch 2700 Loss 5.3116 Accuracy 0.2108
# Epoch 1 Batch 2750 Loss 5.2934 Accuracy 0.2122
# Epoch 1 Batch 2800 Loss 5.2762 Accuracy 0.2135
# Epoch 1 Batch 2850 Loss 5.2594 Accuracy 0.2148
# Epoch 1 Batch 2900 Loss 5.2425 Accuracy 0.2161
# Epoch 1 Batch 2950 Loss 5.2262 Accuracy 0.2173
# Epoch 1 Batch 3000 Loss 5.2103 Accuracy 0.2185
# Epoch 1 Batch 3050 Loss 5.1943 Accuracy 0.2198
# Epoch 1 Batch 3100 Loss 5.1787 Accuracy 0.2210
# Epoch 1 Batch 3150 Loss 5.1633 Accuracy 0.2223
# Epoch 1 Batch 3200 Loss 5.1486 Accuracy 0.2234
# Epoch 1 Batch 3250 Loss 5.1342 Accuracy 0.2245
# Epoch 1 Loss 5.1339 Accuracy 0.2245
# Time taken for 1 epoch: 918.45 secs
#
# Epoch 2 Batch 0 Loss 4.0885 Accuracy 0.3149
# Epoch 2 Batch 50 Loss 4.1627 Accuracy 0.3004
# Epoch 2 Batch 100 Loss 4.1615 Accuracy 0.3004
# Epoch 2 Batch 150 Loss 4.1548 Accuracy 0.3014
# Epoch 2 Batch 200 Loss 4.1471 Accuracy 0.3030
# Epoch 2 Batch 250 Loss 4.1390 Accuracy 0.3043
# Epoch 2 Batch 300 Loss 4.1311 Accuracy 0.3052
# Epoch 2 Batch 350 Loss 4.1277 Accuracy 0.3058
# Epoch 2 Batch 400 Loss 4.1181 Accuracy 0.3071
# Epoch 2 Batch 450 Loss 4.1119 Accuracy 0.3079
# Epoch 2 Batch 500 Loss 4.1053 Accuracy 0.3085
# Epoch 2 Batch 550 Loss 4.0983 Accuracy 0.3093
# Epoch 2 Batch 600 Loss 4.0921 Accuracy 0.3099
# Epoch 2 Batch 650 Loss 4.0836 Accuracy 0.3109
# Epoch 2 Batch 700 Loss 4.0762 Accuracy 0.3119
# Epoch 2 Batch 750 Loss 4.0696 Accuracy 0.3127
# Epoch 2 Batch 800 Loss 4.0637 Accuracy 0.3134
# Epoch 2 Batch 850 Loss 4.0562 Accuracy 0.3145
# Epoch 2 Batch 900 Loss 4.0489 Accuracy 0.3153
# Epoch 2 Batch 950 Loss 4.0423 Accuracy 0.3160
# Epoch 2 Batch 1000 Loss 4.0347 Accuracy 0.3170
# Epoch 2 Batch 1050 Loss 4.0270 Accuracy 0.3179
# Epoch 2 Batch 1100 Loss 4.0199 Accuracy 0.3188
# Epoch 2 Batch 1150 Loss 4.0130 Accuracy 0.3195
# Epoch 2 Batch 1200 Loss 4.0056 Accuracy 0.3205
# Epoch 2 Batch 1250 Loss 3.9990 Accuracy 0.3212
# Epoch 2 Batch 1300 Loss 3.9910 Accuracy 0.3222
# Epoch 2 Batch 1350 Loss 3.9845 Accuracy 0.3231
# Epoch 2 Batch 1400 Loss 3.9767 Accuracy 0.3239
# Epoch 2 Batch 1450 Loss 3.9701 Accuracy 0.3246
# Epoch 2 Batch 1500 Loss 3.9632 Accuracy 0.3255
# Epoch 2 Batch 1550 Loss 3.9574 Accuracy 0.3262
# Epoch 2 Batch 1600 Loss 3.9502 Accuracy 0.3270
# Epoch 2 Batch 1650 Loss 3.9433 Accuracy 0.3279
# Epoch 2 Batch 1700 Loss 3.9368 Accuracy 0.3287
# Epoch 2 Batch 1750 Loss 3.9302 Accuracy 0.3295
# Epoch 2 Batch 1800 Loss 3.9226 Accuracy 0.3305
# Epoch 2 Batch 1850 Loss 3.9169 Accuracy 0.3312
# Epoch 2 Batch 1900 Loss 3.9111 Accuracy 0.3319
# Epoch 2 Batch 1950 Loss 3.9054 Accuracy 0.3325
# Epoch 2 Batch 2000 Loss 3.8996 Accuracy 0.3332
# Epoch 2 Batch 2050 Loss 3.8931 Accuracy 0.3340
# Epoch 2 Batch 2100 Loss 3.8867 Accuracy 0.3348
# Epoch 2 Batch 2150 Loss 3.8803 Accuracy 0.3355
# Epoch 2 Batch 2200 Loss 3.8744 Accuracy 0.3362
# Epoch 2 Batch 2250 Loss 3.8679 Accuracy 0.3370
# Epoch 2 Batch 2300 Loss 3.8621 Accuracy 0.3377
# Epoch 2 Batch 2350 Loss 3.8565 Accuracy 0.3383
# Epoch 2 Batch 2400 Loss 3.8512 Accuracy 0.3389
# Epoch 2 Batch 2450 Loss 3.8454 Accuracy 0.3396
# Epoch 2 Batch 2500 Loss 3.8395 Accuracy 0.3403
# Epoch 2 Batch 2550 Loss 3.8338 Accuracy 0.3409
# Epoch 2 Batch 2600 Loss 3.8277 Accuracy 0.3416
# Epoch 2 Batch 2650 Loss 3.8219 Accuracy 0.3424
# Epoch 2 Batch 2700 Loss 3.8158 Accuracy 0.3431
# Epoch 2 Batch 2750 Loss 3.8108 Accuracy 0.3437
# Epoch 2 Batch 2800 Loss 3.8049 Accuracy 0.3444
# Epoch 2 Batch 2850 Loss 3.8001 Accuracy 0.3449
# Epoch 2 Batch 2900 Loss 3.7948 Accuracy 0.3455
# Epoch 2 Batch 2950 Loss 3.7892 Accuracy 0.3462
# Epoch 2 Batch 3000 Loss 3.7836 Accuracy 0.3469
# Epoch 2 Batch 3050 Loss 3.7783 Accuracy 0.3476
# Epoch 2 Batch 3100 Loss 3.7729 Accuracy 0.3482
# Epoch 2 Batch 3150 Loss 3.7675 Accuracy 0.3489
# Epoch 2 Batch 3200 Loss 3.7620 Accuracy 0.3496
# Epoch 2 Batch 3250 Loss 3.7568 Accuracy 0.3502
# Epoch 2 Loss 3.7567 Accuracy 0.3502
# Time taken for 1 epoch: 896.77 secs
#
# Epoch 3 Batch 0 Loss 3.3178 Accuracy 0.4185
# Epoch 3 Batch 50 Loss 3.4066 Accuracy 0.3917
# Epoch 3 Batch 100 Loss 3.4004 Accuracy 0.3915
# Epoch 3 Batch 150 Loss 3.3994 Accuracy 0.3919
# Epoch 3 Batch 200 Loss 3.3898 Accuracy 0.3930
# Epoch 3 Batch 250 Loss 3.3824 Accuracy 0.3940
# Epoch 3 Batch 300 Loss 3.3829 Accuracy 0.3941
# Epoch 3 Batch 350 Loss 3.3795 Accuracy 0.3945
# Epoch 3 Batch 400 Loss 3.3781 Accuracy 0.3947
# Epoch 3 Batch 450 Loss 3.3760 Accuracy 0.3950
# Epoch 3 Batch 500 Loss 3.3737 Accuracy 0.3952
# Epoch 3 Batch 550 Loss 3.3708 Accuracy 0.3957
# Epoch 3 Batch 600 Loss 3.3660 Accuracy 0.3962
# Epoch 3 Batch 650 Loss 3.3609 Accuracy 0.3968
# Epoch 3 Batch 700 Loss 3.3566 Accuracy 0.3975
# Epoch 3 Batch 750 Loss 3.3534 Accuracy 0.3979
# Epoch 3 Batch 800 Loss 3.3481 Accuracy 0.3986
# Epoch 3 Batch 850 Loss 3.3431 Accuracy 0.3994
# Epoch 3 Batch 900 Loss 3.3385 Accuracy 0.3999
# Epoch 3 Batch 950 Loss 3.3358 Accuracy 0.4003
# Epoch 3 Batch 1000 Loss 3.3322 Accuracy 0.4008
# Epoch 3 Batch 1050 Loss 3.3288 Accuracy 0.4013
# Epoch 3 Batch 1100 Loss 3.3254 Accuracy 0.4017
# Epoch 3 Batch 1150 Loss 3.3218 Accuracy 0.4022
# Epoch 3 Batch 1200 Loss 3.3176 Accuracy 0.4028
# Epoch 3 Batch 1250 Loss 3.3155 Accuracy 0.4031
# Epoch 3 Batch 1300 Loss 3.3107 Accuracy 0.4037
# Epoch 3 Batch 1350 Loss 3.3082 Accuracy 0.4039
# Epoch 3 Batch 1400 Loss 3.3048 Accuracy 0.4044
# Epoch 3 Batch 1450 Loss 3.3012 Accuracy 0.4049
# Epoch 3 Batch 1500 Loss 3.2988 Accuracy 0.4052
# Epoch 3 Batch 1550 Loss 3.2970 Accuracy 0.4054
# Epoch 3 Batch 1600 Loss 3.2934 Accuracy 0.4059
# Epoch 3 Batch 1650 Loss 3.2896 Accuracy 0.4063
# Epoch 3 Batch 1700 Loss 3.2869 Accuracy 0.4067
# Epoch 3 Batch 1750 Loss 3.2836 Accuracy 0.4071
# Epoch 3 Batch 1800 Loss 3.2804 Accuracy 0.4075
# Epoch 3 Batch 1850 Loss 3.2779 Accuracy 0.4078
# Epoch 3 Batch 1900 Loss 3.2754 Accuracy 0.4081
# Epoch 3 Batch 1950 Loss 3.2724 Accuracy 0.4085
# Epoch 3 Batch 2000 Loss 3.2695 Accuracy 0.4088
# Epoch 3 Batch 2050 Loss 3.2664 Accuracy 0.4092
# Epoch 3 Batch 2100 Loss 3.2635 Accuracy 0.4096
# Epoch 3 Batch 2150 Loss 3.2609 Accuracy 0.4099
# Epoch 3 Batch 2200 Loss 3.2574 Accuracy 0.4104
# Epoch 3 Batch 2250 Loss 3.2546 Accuracy 0.4107
# Epoch 3 Batch 2300 Loss 3.2530 Accuracy 0.4109
# Epoch 3 Batch 2350 Loss 3.2500 Accuracy 0.4113
# Epoch 3 Batch 2400 Loss 3.2475 Accuracy 0.4116
# Epoch 3 Batch 2450 Loss 3.2449 Accuracy 0.4119
# Epoch 3 Batch 2500 Loss 3.2420 Accuracy 0.4122
# Epoch 3 Batch 2550 Loss 3.2393 Accuracy 0.4126
# Epoch 3 Batch 2600 Loss 3.2368 Accuracy 0.4129
# Epoch 3 Batch 2650 Loss 3.2342 Accuracy 0.4132
# Epoch 3 Batch 2700 Loss 3.2310 Accuracy 0.4136
# Epoch 3 Batch 2750 Loss 3.2282 Accuracy 0.4140
# Epoch 3 Batch 2800 Loss 3.2258 Accuracy 0.4143
# Epoch 3 Batch 2850 Loss 3.2232 Accuracy 0.4146
# Epoch 3 Batch 2900 Loss 3.2206 Accuracy 0.4150
# Epoch 3 Batch 2950 Loss 3.2179 Accuracy 0.4153
# Epoch 3 Batch 3000 Loss 3.2150 Accuracy 0.4156
# Epoch 3 Batch 3050 Loss 3.2123 Accuracy 0.4160
# Epoch 3 Batch 3100 Loss 3.2103 Accuracy 0.4162
# Epoch 3 Batch 3150 Loss 3.2083 Accuracy 0.4165
# Epoch 3 Batch 3200 Loss 3.2063 Accuracy 0.4167
# Epoch 3 Batch 3250 Loss 3.2037 Accuracy 0.4170
# Epoch 3 Loss 3.2037 Accuracy 0.4170
# Time taken for 1 epoch: 893.61 secs
#
# Epoch 4 Batch 0 Loss 2.9508 Accuracy 0.4476
# Epoch 4 Batch 50 Loss 2.9971 Accuracy 0.4434
# Epoch 4 Batch 100 Loss 3.0180 Accuracy 0.4389
# Epoch 4 Batch 150 Loss 3.0280 Accuracy 0.4373
# Epoch 4 Batch 200 Loss 3.0216 Accuracy 0.4378
# Epoch 4 Batch 250 Loss 3.0256 Accuracy 0.4373
# Epoch 4 Batch 300 Loss 3.0259 Accuracy 0.4369
# Epoch 4 Batch 350 Loss 3.0228 Accuracy 0.4378
# Epoch 4 Batch 400 Loss 3.0200 Accuracy 0.4383
# Epoch 4 Batch 450 Loss 3.0202 Accuracy 0.4385
# Epoch 4 Batch 500 Loss 3.0173 Accuracy 0.4386
# Epoch 4 Batch 550 Loss 3.0162 Accuracy 0.4388
# Epoch 4 Batch 600 Loss 3.0130 Accuracy 0.4392
# Epoch 4 Batch 650 Loss 3.0105 Accuracy 0.4396
# Epoch 4 Batch 700 Loss 3.0070 Accuracy 0.4402
# Epoch 4 Batch 750 Loss 3.0054 Accuracy 0.4402
# Epoch 4 Batch 800 Loss 3.0036 Accuracy 0.4404
# Epoch 4 Batch 850 Loss 3.0041 Accuracy 0.4404
# Epoch 4 Batch 900 Loss 3.0028 Accuracy 0.4405
# Epoch 4 Batch 950 Loss 3.0000 Accuracy 0.4409
# Epoch 4 Batch 1000 Loss 2.9984 Accuracy 0.4412
# Epoch 4 Batch 1050 Loss 2.9954 Accuracy 0.4416
# Epoch 4 Batch 1100 Loss 2.9938 Accuracy 0.4418
# Epoch 4 Batch 1150 Loss 2.9926 Accuracy 0.4421
# Epoch 4 Batch 1200 Loss 2.9910 Accuracy 0.4423
# Epoch 4 Batch 1250 Loss 2.9889 Accuracy 0.4426
# Epoch 4 Batch 1300 Loss 2.9868 Accuracy 0.4429
# Epoch 4 Batch 1350 Loss 2.9863 Accuracy 0.4430
# Epoch 4 Batch 1400 Loss 2.9832 Accuracy 0.4435
# Epoch 4 Batch 1450 Loss 2.9815 Accuracy 0.4437
# Epoch 4 Batch 1500 Loss 2.9799 Accuracy 0.4439
# Epoch 4 Batch 1550 Loss 2.9788 Accuracy 0.4441
# Epoch 4 Batch 1600 Loss 2.9775 Accuracy 0.4442
# Epoch 4 Batch 1650 Loss 2.9764 Accuracy 0.4444
# Epoch 4 Batch 1700 Loss 2.9758 Accuracy 0.4444
# Epoch 4 Batch 1750 Loss 2.9743 Accuracy 0.4446
# Epoch 4 Batch 1800 Loss 2.9727 Accuracy 0.4449
# Epoch 4 Batch 1850 Loss 2.9715 Accuracy 0.4450
# Epoch 4 Batch 1900 Loss 2.9697 Accuracy 0.4453
# Epoch 4 Batch 1950 Loss 2.9679 Accuracy 0.4455
# Epoch 4 Batch 2000 Loss 2.9662 Accuracy 0.4457
# Epoch 4 Batch 2050 Loss 2.9647 Accuracy 0.4459
# Epoch 4 Batch 2100 Loss 2.9636 Accuracy 0.4461
# Epoch 4 Batch 2150 Loss 2.9613 Accuracy 0.4464
# Epoch 4 Batch 2200 Loss 2.9606 Accuracy 0.4465
# Epoch 4 Batch 2250 Loss 2.9590 Accuracy 0.4467
# Epoch 4 Batch 2300 Loss 2.9574 Accuracy 0.4469
# Epoch 4 Batch 2350 Loss 2.9563 Accuracy 0.4471
# Epoch 4 Batch 2400 Loss 2.9547 Accuracy 0.4473
# Epoch 4 Batch 2450 Loss 2.9537 Accuracy 0.4473
# Epoch 4 Batch 2500 Loss 2.9523 Accuracy 0.4475
# Epoch 4 Batch 2550 Loss 2.9509 Accuracy 0.4477
# Epoch 4 Batch 2600 Loss 2.9494 Accuracy 0.4479
# Epoch 4 Batch 2650 Loss 2.9471 Accuracy 0.4482
# Epoch 4 Batch 2700 Loss 2.9449 Accuracy 0.4485
# Epoch 4 Batch 2750 Loss 2.9430 Accuracy 0.4488
# Epoch 4 Batch 2800 Loss 2.9419 Accuracy 0.4489
# Epoch 4 Batch 2850 Loss 2.9413 Accuracy 0.4490
# Epoch 4 Batch 2900 Loss 2.9396 Accuracy 0.4492
# Epoch 4 Batch 2950 Loss 2.9383 Accuracy 0.4494
# Epoch 4 Batch 3000 Loss 2.9365 Accuracy 0.4496
# Epoch 4 Batch 3050 Loss 2.9360 Accuracy 0.4497
# Epoch 4 Batch 3100 Loss 2.9348 Accuracy 0.4498
# Epoch 4 Batch 3150 Loss 2.9334 Accuracy 0.4500
# Epoch 4 Batch 3200 Loss 2.9324 Accuracy 0.4501
# Epoch 4 Batch 3250 Loss 2.9315 Accuracy 0.4502
# Epoch 4 Loss 2.9315 Accuracy 0.4502
# Time taken for 1 epoch: 896.15 secs
#
# Epoch 5 Batch 0 Loss 2.7707 Accuracy 0.4773
# Epoch 5 Batch 50 Loss 2.8505 Accuracy 0.4604
# Epoch 5 Batch 100 Loss 2.8349 Accuracy 0.4622
# Epoch 5 Batch 150 Loss 2.8335 Accuracy 0.4620
# Epoch 5 Batch 200 Loss 2.8322 Accuracy 0.4622
# Epoch 5 Batch 250 Loss 2.8339 Accuracy 0.4618
# Epoch 5 Batch 300 Loss 2.8338 Accuracy 0.4618
# Epoch 5 Batch 350 Loss 2.8344 Accuracy 0.4620
# Epoch 5 Batch 400 Loss 2.8328 Accuracy 0.4622
# Epoch 5 Batch 450 Loss 2.8325 Accuracy 0.4624
# Epoch 5 Batch 500 Loss 2.8295 Accuracy 0.4629
# Epoch 5 Batch 550 Loss 2.8254 Accuracy 0.4634
# Epoch 5 Batch 600 Loss 2.8274 Accuracy 0.4630
# Epoch 5 Batch 650 Loss 2.8256 Accuracy 0.4632
# Epoch 5 Batch 700 Loss 2.8230 Accuracy 0.4634
# Epoch 5 Batch 750 Loss 2.8214 Accuracy 0.4636
# Epoch 5 Batch 800 Loss 2.8200 Accuracy 0.4637
# Epoch 5 Batch 850 Loss 2.8165 Accuracy 0.4642
# Epoch 5 Batch 900 Loss 2.8141 Accuracy 0.4646
# Epoch 5 Batch 950 Loss 2.8130 Accuracy 0.4648
# Epoch 5 Batch 1000 Loss 2.8126 Accuracy 0.4649
# Epoch 5 Batch 1050 Loss 2.8109 Accuracy 0.4652
# Epoch 5 Batch 1100 Loss 2.8096 Accuracy 0.4653
# Epoch 5 Batch 1150 Loss 2.8079 Accuracy 0.4655
# Epoch 5 Batch 1200 Loss 2.8060 Accuracy 0.4659
# Epoch 5 Batch 1250 Loss 2.8055 Accuracy 0.4660
# Epoch 5 Batch 1300 Loss 2.8051 Accuracy 0.4660
# Epoch 5 Batch 1350 Loss 2.8040 Accuracy 0.4662
# Epoch 5 Batch 1400 Loss 2.8025 Accuracy 0.4663
# Epoch 5 Batch 1450 Loss 2.8014 Accuracy 0.4665
# Epoch 5 Batch 1500 Loss 2.8007 Accuracy 0.4665
# Epoch 5 Batch 1550 Loss 2.7996 Accuracy 0.4667
# Epoch 5 Batch 1600 Loss 2.7982 Accuracy 0.4669
# Epoch 5 Batch 1650 Loss 2.7976 Accuracy 0.4670
# Epoch 5 Batch 1700 Loss 2.7976 Accuracy 0.4670
# Epoch 5 Batch 1750 Loss 2.7970 Accuracy 0.4671
# Epoch 5 Batch 1800 Loss 2.7960 Accuracy 0.4672
# Epoch 5 Batch 1850 Loss 2.7954 Accuracy 0.4673
# Epoch 5 Batch 1900 Loss 2.7940 Accuracy 0.4675
# Epoch 5 Batch 1950 Loss 2.7929 Accuracy 0.4677
# Epoch 5 Batch 2000 Loss 2.7923 Accuracy 0.4678
# Epoch 5 Batch 2050 Loss 2.7914 Accuracy 0.4680
# Epoch 5 Batch 2100 Loss 2.7907 Accuracy 0.4681
# Epoch 5 Batch 2150 Loss 2.7900 Accuracy 0.4682
# Epoch 5 Batch 2200 Loss 2.7895 Accuracy 0.4683
# Epoch 5 Batch 2250 Loss 2.7887 Accuracy 0.4684
# Epoch 5 Batch 2300 Loss 2.7884 Accuracy 0.4684
# Epoch 5 Batch 2350 Loss 2.7874 Accuracy 0.4685
# Epoch 5 Batch 2400 Loss 2.7862 Accuracy 0.4687
# Epoch 5 Batch 2450 Loss 2.7853 Accuracy 0.4689
# Epoch 5 Batch 2500 Loss 2.7846 Accuracy 0.4690
# Epoch 5 Batch 2550 Loss 2.7834 Accuracy 0.4691
# Epoch 5 Batch 2600 Loss 2.7826 Accuracy 0.4692
# Epoch 5 Batch 2650 Loss 2.7813 Accuracy 0.4694
# Epoch 5 Batch 2700 Loss 2.7801 Accuracy 0.4696
# Epoch 5 Batch 2750 Loss 2.7789 Accuracy 0.4698
# Epoch 5 Batch 2800 Loss 2.7779 Accuracy 0.4699
# Epoch 5 Batch 2850 Loss 2.7779 Accuracy 0.4699
# Epoch 5 Batch 2900 Loss 2.7771 Accuracy 0.4700
# Epoch 5 Batch 2950 Loss 2.7760 Accuracy 0.4702
# Epoch 5 Batch 3000 Loss 2.7749 Accuracy 0.4703
# Epoch 5 Batch 3050 Loss 2.7739 Accuracy 0.4705
# Epoch 5 Batch 3100 Loss 2.7734 Accuracy 0.4706
# Epoch 5 Batch 3150 Loss 2.7722 Accuracy 0.4707
# Epoch 5 Batch 3200 Loss 2.7712 Accuracy 0.4708
# Epoch 5 Batch 3250 Loss 2.7705 Accuracy 0.4709
# Saving checkpoint for epoch 5 at ./checkpoints/train/ckpt-1
# Epoch 5 Loss 2.7704 Accuracy 0.4709
# Time taken for 1 epoch: 895.63 secs
#
# Epoch 6 Batch 0 Loss 2.9409 Accuracy 0.4488
# Epoch 6 Batch 50 Loss 2.7191 Accuracy 0.4771
# Epoch 6 Batch 100 Loss 2.7192 Accuracy 0.4764
# Epoch 6 Batch 150 Loss 2.7099 Accuracy 0.4785
# Epoch 6 Batch 200 Loss 2.7028 Accuracy 0.4799
# Epoch 6 Batch 250 Loss 2.6978 Accuracy 0.4804
# Epoch 6 Batch 300 Loss 2.7031 Accuracy 0.4796
# Epoch 6 Batch 350 Loss 2.7026 Accuracy 0.4796
# Epoch 6 Batch 400 Loss 2.6985 Accuracy 0.4799
# Epoch 6 Batch 450 Loss 2.6943 Accuracy 0.4805
# Epoch 6 Batch 500 Loss 2.6948 Accuracy 0.4805
# Epoch 6 Batch 550 Loss 2.6952 Accuracy 0.4807
# Epoch 6 Batch 600 Loss 2.6968 Accuracy 0.4805
# Epoch 6 Batch 650 Loss 2.6972 Accuracy 0.4804
# Epoch 6 Batch 700 Loss 2.6969 Accuracy 0.4805
# Epoch 6 Batch 750 Loss 2.6960 Accuracy 0.4807
# Epoch 6 Batch 800 Loss 2.6959 Accuracy 0.4808
# Epoch 6 Batch 850 Loss 2.6947 Accuracy 0.4807
# Epoch 6 Batch 900 Loss 2.6938 Accuracy 0.4810
# Epoch 6 Batch 950 Loss 2.6918 Accuracy 0.4814
# Epoch 6 Batch 1000 Loss 2.6906 Accuracy 0.4815
# Epoch 6 Batch 1050 Loss 2.6909 Accuracy 0.4815
# Epoch 6 Batch 1100 Loss 2.6895 Accuracy 0.4816
# Epoch 6 Batch 1150 Loss 2.6874 Accuracy 0.4819
# Epoch 6 Batch 1200 Loss 2.6861 Accuracy 0.4822
# Epoch 6 Batch 1250 Loss 2.6861 Accuracy 0.4823
# Epoch 6 Batch 1300 Loss 2.6856 Accuracy 0.4824
# Epoch 6 Batch 1350 Loss 2.6838 Accuracy 0.4826
# Epoch 6 Batch 1400 Loss 2.6843 Accuracy 0.4825
# Epoch 6 Batch 1450 Loss 2.6844 Accuracy 0.4824
# Epoch 6 Batch 1500 Loss 2.6840 Accuracy 0.4825
# Epoch 6 Batch 1550 Loss 2.6827 Accuracy 0.4826
# Epoch 6 Batch 1600 Loss 2.6813 Accuracy 0.4828
# Epoch 6 Batch 1650 Loss 2.6805 Accuracy 0.4829
# Epoch 6 Batch 1700 Loss 2.6803 Accuracy 0.4829
# Epoch 6 Batch 1750 Loss 2.6794 Accuracy 0.4830
# Epoch 6 Batch 1800 Loss 2.6794 Accuracy 0.4830
# Epoch 6 Batch 1850 Loss 2.6792 Accuracy 0.4830
# Epoch 6 Batch 1900 Loss 2.6796 Accuracy 0.4829
# Epoch 6 Batch 1950 Loss 2.6787 Accuracy 0.4831
# Epoch 6 Batch 2000 Loss 2.6779 Accuracy 0.4832
# Epoch 6 Batch 2050 Loss 2.6774 Accuracy 0.4833
# Epoch 6 Batch 2100 Loss 2.6774 Accuracy 0.4833
# Epoch 6 Batch 2150 Loss 2.6766 Accuracy 0.4834
# Epoch 6 Batch 2200 Loss 2.6756 Accuracy 0.4835
# Epoch 6 Batch 2250 Loss 2.6744 Accuracy 0.4836
# Epoch 6 Batch 2300 Loss 2.6739 Accuracy 0.4837
# Epoch 6 Batch 2350 Loss 2.6731 Accuracy 0.4837
# Epoch 6 Batch 2400 Loss 2.6727 Accuracy 0.4838
# Epoch 6 Batch 2450 Loss 2.6720 Accuracy 0.4840
# Epoch 6 Batch 2500 Loss 2.6713 Accuracy 0.4841
# Epoch 6 Batch 2550 Loss 2.6708 Accuracy 0.4842
# Epoch 6 Batch 2600 Loss 2.6704 Accuracy 0.4843
# Epoch 6 Batch 2650 Loss 2.6697 Accuracy 0.4844
# Epoch 6 Batch 2700 Loss 2.6693 Accuracy 0.4844
# Epoch 6 Batch 2750 Loss 2.6686 Accuracy 0.4846
# Epoch 6 Batch 2800 Loss 2.6679 Accuracy 0.4847
# Epoch 6 Batch 2850 Loss 2.6678 Accuracy 0.4847
# Epoch 6 Batch 2900 Loss 2.6673 Accuracy 0.4848
# Epoch 6 Batch 2950 Loss 2.6667 Accuracy 0.4849
# Epoch 6 Batch 3000 Loss 2.6661 Accuracy 0.4850
# Epoch 6 Batch 3050 Loss 2.6655 Accuracy 0.4850
# Epoch 6 Batch 3100 Loss 2.6651 Accuracy 0.4851
# Epoch 6 Batch 3150 Loss 2.6641 Accuracy 0.4853
# Epoch 6 Batch 3200 Loss 2.6633 Accuracy 0.4854
# Epoch 6 Batch 3250 Loss 2.6630 Accuracy 0.4854
# Epoch 6 Loss 2.6630 Accuracy 0.4854
# Time taken for 1 epoch: 897.33 secs
#
# Epoch 7 Batch 0 Loss 2.4639 Accuracy 0.5139
# Epoch 7 Batch 50 Loss 2.5964 Accuracy 0.4931
# Epoch 7 Batch 100 Loss 2.5900 Accuracy 0.4946
# Epoch 7 Batch 150 Loss 2.6050 Accuracy 0.4921
# Epoch 7 Batch 200 Loss 2.6072 Accuracy 0.4918
# Epoch 7 Batch 250 Loss 2.6131 Accuracy 0.4907
# Epoch 7 Batch 300 Loss 2.6112 Accuracy 0.4912
# Epoch 7 Batch 350 Loss 2.6071 Accuracy 0.4923
# Epoch 7 Batch 400 Loss 2.6098 Accuracy 0.4923
# Epoch 7 Batch 450 Loss 2.6092 Accuracy 0.4926
# Epoch 7 Batch 500 Loss 2.6125 Accuracy 0.4922
# Epoch 7 Batch 550 Loss 2.6129 Accuracy 0.4921
# Epoch 7 Batch 600 Loss 2.6098 Accuracy 0.4925
# Epoch 7 Batch 650 Loss 2.6093 Accuracy 0.4926
# Epoch 7 Batch 700 Loss 2.6120 Accuracy 0.4920
# Epoch 7 Batch 750 Loss 2.6088 Accuracy 0.4925
# Epoch 7 Batch 800 Loss 2.6085 Accuracy 0.4926
# Epoch 7 Batch 850 Loss 2.6075 Accuracy 0.4928
# Epoch 7 Batch 900 Loss 2.6075 Accuracy 0.4929
# Epoch 7 Batch 950 Loss 2.6066 Accuracy 0.4930
# Epoch 7 Batch 1000 Loss 2.6062 Accuracy 0.4930
# Epoch 7 Batch 1050 Loss 2.6064 Accuracy 0.4930
# Epoch 7 Batch 1100 Loss 2.6064 Accuracy 0.4930
# Epoch 7 Batch 1150 Loss 2.6058 Accuracy 0.4931
# Epoch 7 Batch 1200 Loss 2.6056 Accuracy 0.4931
# Epoch 7 Batch 1250 Loss 2.6043 Accuracy 0.4933
# Epoch 7 Batch 1300 Loss 2.6042 Accuracy 0.4933
# Epoch 7 Batch 1350 Loss 2.6034 Accuracy 0.4934
# Epoch 7 Batch 1400 Loss 2.6030 Accuracy 0.4935
# Epoch 7 Batch 1450 Loss 2.6018 Accuracy 0.4937
# Epoch 7 Batch 1500 Loss 2.6018 Accuracy 0.4937
# Epoch 7 Batch 1550 Loss 2.6009 Accuracy 0.4938
# Epoch 7 Batch 1600 Loss 2.6009 Accuracy 0.4938
# Epoch 7 Batch 1650 Loss 2.6004 Accuracy 0.4938
# Epoch 7 Batch 1700 Loss 2.6001 Accuracy 0.4938
# Epoch 7 Batch 1750 Loss 2.6004 Accuracy 0.4938
# Epoch 7 Batch 1800 Loss 2.6002 Accuracy 0.4939
# Epoch 7 Batch 1850 Loss 2.5998 Accuracy 0.4940
# Epoch 7 Batch 1900 Loss 2.5993 Accuracy 0.4940
# Epoch 7 Batch 1950 Loss 2.5984 Accuracy 0.4942
# Epoch 7 Batch 2000 Loss 2.5976 Accuracy 0.4944
# Epoch 7 Batch 2050 Loss 2.5971 Accuracy 0.4944
# Epoch 7 Batch 2100 Loss 2.5963 Accuracy 0.4945
# Epoch 7 Batch 2150 Loss 2.5956 Accuracy 0.4947
# Epoch 7 Batch 2200 Loss 2.5951 Accuracy 0.4947
# Epoch 7 Batch 2250 Loss 2.5942 Accuracy 0.4949
# Epoch 7 Batch 2300 Loss 2.5938 Accuracy 0.4949
# Epoch 7 Batch 2350 Loss 2.5941 Accuracy 0.4949
# Epoch 7 Batch 2400 Loss 2.5928 Accuracy 0.4951
# Epoch 7 Batch 2450 Loss 2.5922 Accuracy 0.4951
# Epoch 7 Batch 2500 Loss 2.5921 Accuracy 0.4952
# Epoch 7 Batch 2550 Loss 2.5917 Accuracy 0.4952
# Epoch 7 Batch 2600 Loss 2.5913 Accuracy 0.4952
# Epoch 7 Batch 2650 Loss 2.5905 Accuracy 0.4954
# Epoch 7 Batch 2700 Loss 2.5897 Accuracy 0.4955
# Epoch 7 Batch 2750 Loss 2.5892 Accuracy 0.4956
# Epoch 7 Batch 2800 Loss 2.5890 Accuracy 0.4956
# Epoch 7 Batch 2850 Loss 2.5890 Accuracy 0.4956
# Epoch 7 Batch 2900 Loss 2.5885 Accuracy 0.4957
# Epoch 7 Batch 2950 Loss 2.5882 Accuracy 0.4958
# Epoch 7 Batch 3000 Loss 2.5873 Accuracy 0.4959
# Epoch 7 Batch 3050 Loss 2.5868 Accuracy 0.4960
# Epoch 7 Batch 3100 Loss 2.5865 Accuracy 0.4960
# Epoch 7 Batch 3150 Loss 2.5863 Accuracy 0.4960
# Epoch 7 Batch 3200 Loss 2.5859 Accuracy 0.4961
# Epoch 7 Batch 3250 Loss 2.5852 Accuracy 0.4962
# Epoch 7 Loss 2.5851 Accuracy 0.4962
# Time taken for 1 epoch: 898.21 secs
#
# Epoch 8 Batch 0 Loss 2.3752 Accuracy 0.5167
# Epoch 8 Batch 50 Loss 2.5439 Accuracy 0.5004
# Epoch 8 Batch 100 Loss 2.5487 Accuracy 0.5005
# Epoch 8 Batch 150 Loss 2.5479 Accuracy 0.5015
# Epoch 8 Batch 200 Loss 2.5437 Accuracy 0.5024
# Epoch 8 Batch 250 Loss 2.5437 Accuracy 0.5022
# Epoch 8 Batch 300 Loss 2.5496 Accuracy 0.5010
# Epoch 8 Batch 350 Loss 2.5502 Accuracy 0.5006
# Epoch 8 Batch 400 Loss 2.5450 Accuracy 0.5013
# Epoch 8 Batch 450 Loss 2.5472 Accuracy 0.5010
# Epoch 8 Batch 500 Loss 2.5444 Accuracy 0.5015
# Epoch 8 Batch 550 Loss 2.5456 Accuracy 0.5013
# Epoch 8 Batch 600 Loss 2.5450 Accuracy 0.5014
# Epoch 8 Batch 650 Loss 2.5448 Accuracy 0.5014
# Epoch 8 Batch 700 Loss 2.5436 Accuracy 0.5015
# Epoch 8 Batch 750 Loss 2.5445 Accuracy 0.5014
# Epoch 8 Batch 800 Loss 2.5437 Accuracy 0.5016
# Epoch 8 Batch 850 Loss 2.5413 Accuracy 0.5022
# Epoch 8 Batch 900 Loss 2.5404 Accuracy 0.5024
# Epoch 8 Batch 950 Loss 2.5399 Accuracy 0.5024
# Epoch 8 Batch 1000 Loss 2.5395 Accuracy 0.5024
# Epoch 8 Batch 1050 Loss 2.5382 Accuracy 0.5026
# Epoch 8 Batch 1100 Loss 2.5382 Accuracy 0.5027
# Epoch 8 Batch 1150 Loss 2.5382 Accuracy 0.5027
# Epoch 8 Batch 1200 Loss 2.5370 Accuracy 0.5028
# Epoch 8 Batch 1250 Loss 2.5376 Accuracy 0.5027
# Epoch 8 Batch 1300 Loss 2.5364 Accuracy 0.5029
# Epoch 8 Batch 1350 Loss 2.5362 Accuracy 0.5028
# Epoch 8 Batch 1400 Loss 2.5360 Accuracy 0.5028
# Epoch 8 Batch 1450 Loss 2.5356 Accuracy 0.5029
# Epoch 8 Batch 1500 Loss 2.5356 Accuracy 0.5029
# Epoch 8 Batch 1550 Loss 2.5356 Accuracy 0.5029
# Epoch 8 Batch 1600 Loss 2.5355 Accuracy 0.5029
# Epoch 8 Batch 1650 Loss 2.5353 Accuracy 0.5029
# Epoch 8 Batch 1700 Loss 2.5349 Accuracy 0.5030
# Epoch 8 Batch 1750 Loss 2.5350 Accuracy 0.5030
# Epoch 8 Batch 1800 Loss 2.5357 Accuracy 0.5030
# Epoch 8 Batch 1850 Loss 2.5350 Accuracy 0.5031
# Epoch 8 Batch 1900 Loss 2.5348 Accuracy 0.5031
# Epoch 8 Batch 1950 Loss 2.5348 Accuracy 0.5031
# Epoch 8 Batch 2000 Loss 2.5347 Accuracy 0.5031
# Epoch 8 Batch 2050 Loss 2.5343 Accuracy 0.5032
# Epoch 8 Batch 2100 Loss 2.5334 Accuracy 0.5034
# Epoch 8 Batch 2150 Loss 2.5330 Accuracy 0.5034
# Epoch 8 Batch 2200 Loss 2.5331 Accuracy 0.5033
# Epoch 8 Batch 2250 Loss 2.5326 Accuracy 0.5034
# Epoch 8 Batch 2300 Loss 2.5318 Accuracy 0.5035
# Epoch 8 Batch 2350 Loss 2.5316 Accuracy 0.5036
# Epoch 8 Batch 2400 Loss 2.5309 Accuracy 0.5037
# Epoch 8 Batch 2450 Loss 2.5307 Accuracy 0.5037
# Epoch 8 Batch 2500 Loss 2.5304 Accuracy 0.5038
# Epoch 8 Batch 2550 Loss 2.5295 Accuracy 0.5039
# Epoch 8 Batch 2600 Loss 2.5291 Accuracy 0.5040
# Epoch 8 Batch 2650 Loss 2.5283 Accuracy 0.5041
# Epoch 8 Batch 2700 Loss 2.5279 Accuracy 0.5041
# Epoch 8 Batch 2750 Loss 2.5274 Accuracy 0.5042
# Epoch 8 Batch 2800 Loss 2.5269 Accuracy 0.5043
# Epoch 8 Batch 2850 Loss 2.5269 Accuracy 0.5043
# Epoch 8 Batch 2900 Loss 2.5268 Accuracy 0.5043
# Epoch 8 Batch 2950 Loss 2.5269 Accuracy 0.5043
# Epoch 8 Batch 3000 Loss 2.5265 Accuracy 0.5043
# Epoch 8 Batch 3050 Loss 2.5262 Accuracy 0.5043
# Epoch 8 Batch 3100 Loss 2.5261 Accuracy 0.5043
# Epoch 8 Batch 3150 Loss 2.5257 Accuracy 0.5044
# Epoch 8 Batch 3200 Loss 2.5250 Accuracy 0.5045
# Epoch 8 Batch 3250 Loss 2.5247 Accuracy 0.5046
# Epoch 8 Loss 2.5246 Accuracy 0.5046
# Time taken for 1 epoch: 898.45 secs
#
# Epoch 9 Batch 0 Loss 2.5366 Accuracy 0.5183
# Epoch 9 Batch 50 Loss 2.4978 Accuracy 0.5089
# Epoch 9 Batch 100 Loss 2.5123 Accuracy 0.5063
# Epoch 9 Batch 150 Loss 2.5052 Accuracy 0.5072
# Epoch 9 Batch 200 Loss 2.4991 Accuracy 0.5087
# Epoch 9 Batch 250 Loss 2.5010 Accuracy 0.5083
# Epoch 9 Batch 300 Loss 2.4952 Accuracy 0.5086
# Epoch 9 Batch 350 Loss 2.4942 Accuracy 0.5086
# Epoch 9 Batch 400 Loss 2.4960 Accuracy 0.5082
# Epoch 9 Batch 450 Loss 2.4979 Accuracy 0.5081
# Epoch 9 Batch 500 Loss 2.4944 Accuracy 0.5088
# Epoch 9 Batch 550 Loss 2.4967 Accuracy 0.5084
# Epoch 9 Batch 600 Loss 2.4969 Accuracy 0.5083
# Epoch 9 Batch 650 Loss 2.4955 Accuracy 0.5084
# Epoch 9 Batch 700 Loss 2.4923 Accuracy 0.5089
# Epoch 9 Batch 750 Loss 2.4909 Accuracy 0.5091
# Epoch 9 Batch 800 Loss 2.4919 Accuracy 0.5090
# Epoch 9 Batch 850 Loss 2.4901 Accuracy 0.5093
# Epoch 9 Batch 900 Loss 2.4905 Accuracy 0.5092
# Epoch 9 Batch 950 Loss 2.4904 Accuracy 0.5091
# Epoch 9 Batch 1000 Loss 2.4887 Accuracy 0.5094
# Epoch 9 Batch 1050 Loss 2.4874 Accuracy 0.5095
# Epoch 9 Batch 1100 Loss 2.4870 Accuracy 0.5096
# Epoch 9 Batch 1150 Loss 2.4870 Accuracy 0.5098
# Epoch 9 Batch 1200 Loss 2.4867 Accuracy 0.5098
# Epoch 9 Batch 1250 Loss 2.4874 Accuracy 0.5097
# Epoch 9 Batch 1300 Loss 2.4865 Accuracy 0.5099
# Epoch 9 Batch 1350 Loss 2.4858 Accuracy 0.5101
# Epoch 9 Batch 1400 Loss 2.4852 Accuracy 0.5102
# Epoch 9 Batch 1450 Loss 2.4843 Accuracy 0.5103
# Epoch 9 Batch 1500 Loss 2.4842 Accuracy 0.5103
# Epoch 9 Batch 1550 Loss 2.4850 Accuracy 0.5102
# Epoch 9 Batch 1600 Loss 2.4851 Accuracy 0.5102
# Epoch 9 Batch 1650 Loss 2.4849 Accuracy 0.5103
# Epoch 9 Batch 1700 Loss 2.4844 Accuracy 0.5103
# Epoch 9 Batch 1750 Loss 2.4844 Accuracy 0.5103
# Epoch 9 Batch 1800 Loss 2.4834 Accuracy 0.5105
# Epoch 9 Batch 1850 Loss 2.4836 Accuracy 0.5104
# Epoch 9 Batch 1900 Loss 2.4835 Accuracy 0.5104
# Epoch 9 Batch 1950 Loss 2.4833 Accuracy 0.5104
# Epoch 9 Batch 2000 Loss 2.4833 Accuracy 0.5104
# Epoch 9 Batch 2050 Loss 2.4837 Accuracy 0.5104
# Epoch 9 Batch 2100 Loss 2.4833 Accuracy 0.5105
# Epoch 9 Batch 2150 Loss 2.4832 Accuracy 0.5105
# Epoch 9 Batch 2200 Loss 2.4835 Accuracy 0.5104
# Epoch 9 Batch 2250 Loss 2.4833 Accuracy 0.5105
# Epoch 9 Batch 2300 Loss 2.4827 Accuracy 0.5105
# Epoch 9 Batch 2350 Loss 2.4822 Accuracy 0.5106
# Epoch 9 Batch 2400 Loss 2.4823 Accuracy 0.5106
# Epoch 9 Batch 2450 Loss 2.4816 Accuracy 0.5107
# Epoch 9 Batch 2500 Loss 2.4814 Accuracy 0.5107
# Epoch 9 Batch 2550 Loss 2.4808 Accuracy 0.5108
# Epoch 9 Batch 2600 Loss 2.4806 Accuracy 0.5108
# Epoch 9 Batch 2650 Loss 2.4798 Accuracy 0.5110
# Epoch 9 Batch 2700 Loss 2.4798 Accuracy 0.5110
# Epoch 9 Batch 2750 Loss 2.4796 Accuracy 0.5110
# Epoch 9 Batch 2800 Loss 2.4795 Accuracy 0.5110
# Epoch 9 Batch 2850 Loss 2.4796 Accuracy 0.5110
# Epoch 9 Batch 2900 Loss 2.4791 Accuracy 0.5111
# Epoch 9 Batch 2950 Loss 2.4788 Accuracy 0.5111
# Epoch 9 Batch 3000 Loss 2.4789 Accuracy 0.5111
# Epoch 9 Batch 3050 Loss 2.4788 Accuracy 0.5111
# Epoch 9 Batch 3100 Loss 2.4786 Accuracy 0.5112
# Epoch 9 Batch 3150 Loss 2.4784 Accuracy 0.5112
# Epoch 9 Batch 3200 Loss 2.4781 Accuracy 0.5112
# Epoch 9 Batch 3250 Loss 2.4776 Accuracy 0.5113
# Epoch 9 Loss 2.4776 Accuracy 0.5113
# Time taken for 1 epoch: 895.30 secs
#
# Epoch 10 Batch 0 Loss 2.5448 Accuracy 0.4832
# Epoch 10 Batch 50 Loss 2.4449 Accuracy 0.5165
# Epoch 10 Batch 100 Loss 2.4385 Accuracy 0.5176
# Epoch 10 Batch 150 Loss 2.4448 Accuracy 0.5164
# Epoch 10 Batch 200 Loss 2.4478 Accuracy 0.5159
# Epoch 10 Batch 250 Loss 2.4528 Accuracy 0.5151
# Epoch 10 Batch 300 Loss 2.4564 Accuracy 0.5145
# Epoch 10 Batch 350 Loss 2.4558 Accuracy 0.5146
# Epoch 10 Batch 400 Loss 2.4517 Accuracy 0.5151
# Epoch 10 Batch 450 Loss 2.4553 Accuracy 0.5147
# Epoch 10 Batch 500 Loss 2.4533 Accuracy 0.5146
# Epoch 10 Batch 550 Loss 2.4528 Accuracy 0.5148
# Epoch 10 Batch 600 Loss 2.4499 Accuracy 0.5152
# Epoch 10 Batch 650 Loss 2.4490 Accuracy 0.5152
# Epoch 10 Batch 700 Loss 2.4485 Accuracy 0.5154
# Epoch 10 Batch 750 Loss 2.4500 Accuracy 0.5153
# Epoch 10 Batch 800 Loss 2.4508 Accuracy 0.5153
# Epoch 10 Batch 850 Loss 2.4486 Accuracy 0.5156
# Epoch 10 Batch 900 Loss 2.4482 Accuracy 0.5157
# Epoch 10 Batch 950 Loss 2.4486 Accuracy 0.5157
# Epoch 10 Batch 1000 Loss 2.4483 Accuracy 0.5157
# Epoch 10 Batch 1050 Loss 2.4481 Accuracy 0.5157
# Epoch 10 Batch 1100 Loss 2.4468 Accuracy 0.5159
# Epoch 10 Batch 1150 Loss 2.4458 Accuracy 0.5160
# Epoch 10 Batch 1200 Loss 2.4456 Accuracy 0.5160
# Epoch 10 Batch 1250 Loss 2.4449 Accuracy 0.5161
# Epoch 10 Batch 1300 Loss 2.4452 Accuracy 0.5161
# Epoch 10 Batch 1350 Loss 2.4448 Accuracy 0.5161
# Epoch 10 Batch 1400 Loss 2.4454 Accuracy 0.5160
# Epoch 10 Batch 1450 Loss 2.4456 Accuracy 0.5160
# Epoch 10 Batch 1500 Loss 2.4464 Accuracy 0.5159
# Epoch 10 Batch 1550 Loss 2.4461 Accuracy 0.5160
# Epoch 10 Batch 1600 Loss 2.4465 Accuracy 0.5159
# Epoch 10 Batch 1650 Loss 2.4469 Accuracy 0.5158
# Epoch 10 Batch 1700 Loss 2.4462 Accuracy 0.5159
# Epoch 10 Batch 1750 Loss 2.4452 Accuracy 0.5160
# Epoch 10 Batch 1800 Loss 2.4441 Accuracy 0.5162
# Epoch 10 Batch 1850 Loss 2.4442 Accuracy 0.5162
# Epoch 10 Batch 1900 Loss 2.4426 Accuracy 0.5164
# Epoch 10 Batch 1950 Loss 2.4424 Accuracy 0.5165
# Epoch 10 Batch 2000 Loss 2.4436 Accuracy 0.5163
# Epoch 10 Batch 2050 Loss 2.4434 Accuracy 0.5164
# Epoch 10 Batch 2100 Loss 2.4433 Accuracy 0.5163
# Epoch 10 Batch 2150 Loss 2.4437 Accuracy 0.5162
# Epoch 10 Batch 2200 Loss 2.4437 Accuracy 0.5163
# Epoch 10 Batch 2250 Loss 2.4437 Accuracy 0.5163
# Epoch 10 Batch 2300 Loss 2.4430 Accuracy 0.5164
# Epoch 10 Batch 2350 Loss 2.4430 Accuracy 0.5164
# Epoch 10 Batch 2400 Loss 2.4427 Accuracy 0.5165
# Epoch 10 Batch 2450 Loss 2.4421 Accuracy 0.5166
# Epoch 10 Batch 2500 Loss 2.4416 Accuracy 0.5166
# Epoch 10 Batch 2550 Loss 2.4412 Accuracy 0.5167
# Epoch 10 Batch 2600 Loss 2.4408 Accuracy 0.5168
# Epoch 10 Batch 2650 Loss 2.4406 Accuracy 0.5168
# Epoch 10 Batch 2700 Loss 2.4403 Accuracy 0.5169
# Epoch 10 Batch 2750 Loss 2.4400 Accuracy 0.5169
# Epoch 10 Batch 2800 Loss 2.4392 Accuracy 0.5170
# Epoch 10 Batch 2850 Loss 2.4393 Accuracy 0.5170
# Epoch 10 Batch 2900 Loss 2.4391 Accuracy 0.5170
# Epoch 10 Batch 2950 Loss 2.4389 Accuracy 0.5170
# Epoch 10 Batch 3000 Loss 2.4392 Accuracy 0.5170
# Epoch 10 Batch 3050 Loss 2.4390 Accuracy 0.5170
# Epoch 10 Batch 3100 Loss 2.4387 Accuracy 0.5171
# Epoch 10 Batch 3150 Loss 2.4386 Accuracy 0.5171
# Epoch 10 Batch 3200 Loss 2.4383 Accuracy 0.5171
# Epoch 10 Batch 3250 Loss 2.4383 Accuracy 0.5171
# Saving checkpoint for epoch 10 at ./checkpoints/train/ckpt-2
# Epoch 10 Loss 2.4383 Accuracy 0.5171
# Time taken for 1 epoch: 896.32 secs

# %%
class Translator(tf.Module):
  def __init__(self, tokenizers, transformer):
    self.tokenizers = tokenizers
    self.transformer = transformer

  def __call__(self, sentence, max_length=20):
    assert isinstance(sentence, tf.Tensor)
    if len(sentence.shape) == 0:
      sentence = sentence[tf.newaxis]

    sentence = self.tokenizers.ru.tokenize(sentence).to_tensor()

    encoder_input = sentence

    start_end = self.tokenizers.en.tokenize([''])[0]
    start = start_end[0][tf.newaxis]
    end = start_end[1][tf.newaxis]

    output_array = tf.TensorArray(dtype=tf.int64, size=0, dynamic_size=True)
    output_array = output_array.write(0, start)

    for i in tf.range(max_length):
        output = tf.transpose(output_array.stack())
        predictions = self.transformer([encoder_input, output], training=False)

        predictions = predictions[:, -1:, :]

        predicted_id = tf.argmax(predictions, axis=-1)

        output_array = output_array.write(i+1, predicted_id[0])

        if predicted_id == end:
            break

    output = tf.transpose(output_array.stack())
    text = self.tokenizers.en.detokenize(output)[0]

    tokens = self.tokenizers.en.lookup(output)[0]

    return text, tokens

# %%
translator = Translator(tokenizers, transformer)

# %%
def print_translation(sentence, tokens, ground_truth):
  print(f'{"Input:":15s}: {sentence}')
  print(f'{"Prediction":15s}: {tokens.numpy().decode("utf-8")}')
  print(f'{"Ground truth":15s}: {ground_truth}')

# %%
sentence = "Привет."
ground_truth = "Hi."

translated_text, translated_tokens= translator(
    tf.constant(sentence))
print_translation(sentence, translated_text, ground_truth)
# Out:
# Input:         : Привет.
# Prediction     : hello .
# Ground truth   : Hi.

# %%
class ExportTranslator(tf.Module):
  def __init__(self, translator):
    self.translator = translator

  @tf.function(input_signature=[tf.TensorSpec(shape=[], dtype=tf.string)])
  def __call__(self, sentence):
    (result, tokens) = self.translator(sentence, max_length=100)

    return result

# %%
translator = ExportTranslator(translator)

# %%
translator("Как твои дела?").numpy()
# Out:
# b'how do you do that ?'

# %%
tf.saved_model.save(translator, export_dir='ru_eng_translator')
# Out:
# WARNING:absl:Found untraced functions such as embedding_layer_call_fn, embedding_layer_call_and_return_conditional_losses, dropout_8_layer_call_fn, dropout_8_layer_call_and_return_conditional_losses, embedding_1_layer_call_fn while saving (showing 5 of 560). These functions will not be directly callable after loading.

# %%
reloaded = tf.saved_model.load('ru_eng_translator')

# %%
reloaded("Как дела?").numpy()
# Out:
# b'how does it work ?'
